# %%
#denny

# %%
#berga

# %%
#pier

### ARTISTI
[
    { // Artista 1
        "_id": "A1",
        "artista": {"nome_arte": "Ligabue", "nome": "Luciano", "cognome": "Ligabue"},
        "lista_eventi": []
    },
    { // 2
        "_id": "A2",
        "artista": {"nome_arte": "Club Dogo", "nome": "", "cognome": ""},
        "lista_eventi": []
    },
    { // 3
        "_id": "A3",
        "artista": {"nome_arte": "Annalisa", "nome": "", "cognome": ""},
        "lista_eventi": []
    },
    { // 4
        "_id": "A4",
        "artista": {"nome_arte": "Nayt", "nome": "", "cognome": ""},
        "lista_eventi": []
    },
    { // 5
        "_id": "A5",
        "artista": {"nome_arte": "Eros Ramazzotti", "nome": "", "cognome": ""},
        "lista_eventi": []
    },
    { // 6
        "_id": "A6",
        "artista": {"nome_arte": "Avril Lavigne", "nome": "", "cognome": ""},
        "lista_eventi": []
    },
    { // 7
        "_id": "A7",
        "artista": {"nome_arte": "Blink-182", "nome": "", "cognome": ""},
        "lista_eventi": []
    },
    { // 8
        "_id": "A8",
        "artista": {"nome_arte": "Simple Plan", "nome": "", "cognome": ""},
        "lista_eventi": []
    },
    { // 9
        "_id": "A9",
        "artista": {"nome_arte": "Sum 41", "nome": "", "cognome": ""},
        "lista_eventi": []
    },
    { // 10
        "_id": "A10",
        "artista": {"nome_arte": "Pinguini Tattici Nucleari", "nome": "", "cognome": ""},
        "lista_eventi": []
    }
]


### EVENTI
[
    {  // Evento 1
        "_id": "E1",
       "nome_evento": "Eros Ramazzotti World Tour",
       "id_artisti": [],  //Eros 
       "data": "2024-08-15",
       "ora": "16:00:00",
       "id_location": ,
       "biglietti": {
            "disponibili": 5000,
            "prezzo": 40,
            "id_ultimo_biglietto": 0,
       }
    },
    {  // Evento 2
        "_id": "E2",
        "nome_evento": "Hello World Tour - Milano",
        "id_artisti": [], //Pinguini
        "data": "2025-06-17", 
        "ora": "16:00:00",
        "id_location": ,
        "biglietti": {
             "disponibili": 5000,
             "prezzo": 50,
             "id_ultimo_biglietto": 0,
        }
    },
    {  // Evento 3 
        "_id": "E3",
        "nome_evento": "One More Time Tour - Milan",
        "id_artisti": [], //Blink
        "data": "2025-09-09",
        "ora": "16:00:00",
        "id_location": ,
        "biglietti": {
             "disponibili": 5000,
             "prezzo": 30,
             "id_ultimo_biglietto": 0,
        }
    },
    {  // Evento 4
        "_id": "E4",
        "nome_evento": "Heaven Tour - Milan",
        "id_artisti": [], // Sum 41
        "data": "2025-07-07",
        "ora": "16:00:00",
        "id_location": ,
        "biglietti": {
             "disponibili": 5000,
             "prezzo": 30,
             "id_ultimo_biglietto": 0,
        }
    },
    { // Evento 5
        "_id": "E5",
        "nome_evento": "Heaven Tour - Rome",
        "id_artisti": [], //Sum 41
        "data": "2025-07-12",
        "ora": "16:00:00",
        "id_location": ,
        "biglietti": {
             "disponibili": 5000,
             "prezzo": 35,
             "id_ultimo_biglietto": 0,
        }
    },
    {  // Evento 6
        "_id": "E6",
        "nome_evento": "One More Time Tour - Rome",
        "id_artisti": [], // Blink
        "data": "2025-08-09",
        "ora": "16:00:00",
        "id_location": ,
        "biglietti": {
             "disponibili": 5000,
             "prezzo": 40,
             "id_ultimo_biglietto": 0,
        }
    },
    { // Evento 7
        "_id": "E7",
        "nome_evento": "Habitat Summer Tour - Milano",
        "id_artisti": [], // Nayt
        "data": "2024-10-05",
        "ora": "16:00:00",
        "id_location": ,
        "biglietti": {
             "disponibili": 5000,
             "prezzo": 40,
             "id_ultimo_biglietto": 0,
        }
    },
    { // Evento 8
        "_id": "E8",
        "nome_evento": "Habitat Summer Tour - Roma",
        "id_artisti": [],  //Nayt
        "data": "2024-10-10",
        "ora": "16:00:00",
        "id_location": ,
        "biglietti": {
             "disponibili": 5000,
             "prezzo": 40,
             "id_ultimo_biglietto": 0,
        }
    },
    { // Evento 9
        "_id": "E9",
        "nome_evento": "Habitat Summer Tour - Padova",
        "id_artisti": [],  //Nayt
        "data": "2024-10-15",
        "ora": "16:00:00",
        "id_location": ,
        "biglietti": {
             "disponibili": 5000,
             "prezzo": 30,
             "id_ultimo_biglietto": 0,
        }
    },
    {  //Evento 10
        "_id": "E10",
        "nome_evento": "Tutti nel Vortice Tour - Padova", 
        "id_artisti": [], // Annalisa
        "data": "2024-10-11",
        "ora": "16:00:00",
        "id_location": ,
        "biglietti": {
             "disponibili": 5000,
             "prezzo": 30,
             "id_ultimo_biglietto": 0,
        }
    }
]


### LOCATIONS
[
{ // Location 1
    "_id": "L1",
    "location_name": "Fabrique",
    "citta": "Milano",
    "stato": "Italia",
    "geolocation": {
        "type": "Point", 
        "coordinates": [ 45.447062, 9.252403]
    }
},
{ // 2
    "_id": "L2",
    "location_name": "Alcatraz",
    "citta": "Milano",
    "stato": "Italia",
    "geolocation": {
        "type": "Point", 
        "coordinates": [45.494072, 9.182444]
    }
},
{ // 3 
    "_id": "L3",
    "location_name": "Magazzini Generali",
    "citta": "Milano",
    "stato": "Italia",
    "geolocation": {
        "type": "Point", 
        "coordinates": [45.448053, 9.205367]
    }
},
{ // 4
    "_id": "L4",
    "location_name": "Stadio Olimpico",
    "citta": "Roma",
    "stato": "Italia",
    "geolocation": {
        "type": "Point", 
        "coordinates": [41.933900, 12.454553]
    }
},
{ // 5
    "_id": "L5",
    "location_name": "PalaEur",
    "citta": "Roma",
    "stato": "Italia",
    "geolocation": {
        "type": "Point", 
        "coordinates": [41.825842, 12.467805]
    }
},
{ // 6
    "_id": "L6",
    "location_name": "Circo Massimo",
    "citta": "Roma",
    "stato": "Italia",
    "geolocation": {
        "type": "Point", 
        "coordinates": [41.885236, 12.485645]
    }
},
{ // 7
    "_id": "L7",
    "location_name": "Palapartenope",
    "citta": "Napoli",
    "stato": "Italia",
    "geolocation": {
        "type": "Point", 
        "coordinates": [40.826172, 14.194357]
    }
},
{ // 8
    "_id": "L8",
    "location_name": "PalaEldo",
    "citta": "Napoli",
    "stato": "Italia",
    "geolocation": {
        "type": "Point", 
        "coordinates": [40.823826, 14.191144]
    }
},
{ // 9
    "_id": "L9",
    "location_name": "Pala Alpitour",
    "citta": "Torino",
    "stato": "Italia",
    "geolocation": {
        "type": "Point", 
        "coordinates": [45.041410, 7.652550]
    }
},
{ // 10
    "_id": "L10",
    "location_name": "Teatro Regio",
    "citta": "Torino",
    "stato": "Italia",
    "geolocation": {
        "type": "Point", 
        "coordinates": [45.070079, 7.693291]
    }
}
]

# %%
#madda

#location
{
    "location_name": 'Ippodromo di San Siro',
    "citta": 'Milano',
    "stato": 'Italia',
    "geolocation": {
        "type": "Point", 
        "coordinates": [9.1405, 45.4836]
    }
}

{
    "location_name": 'Arena',
    "citta": 'Verona',
    "stato": 'Italia',
    "geolocation": {
        "type": "Point", 
        "coordinates": [10.9944, 45.4386]
    }
}

{
    "location_name": 'Stadio GEOX',
    "citta": 'Padova',
    "stato": 'Italia',
    "geolocation": {
        "type": "Point", 
        "coordinates": [11.8850, 45.4186]
    }
}


{
    "location_name": 'Mediolanum Forum',
    "citta": 'Milano',
    "stato": 'Italia',
    "geolocation": {
        "type": "Point", 
        "coordinates": [9.1427, 45.4070]
    }
}

{
    "location_name": 'Teatro Comunale di Vicenza',
    "citta": 'Vicenza',
    "stato": 'Italia',
    "geolocation": {
        "type": "Point", 
        "coordinates": [11.5430, 45.5469]
    }
}

{
    "location_name": 'Villa Contarini',
    "citta": 'Padova',
    "stato": 'Italia',
    "geolocation": {
        "type": "Point", 
        "coordinates": [11.7765, 45.5543]
    }
}

{
    "location_name": 'Castello Scaligero',
    "citta": 'Verona',
    "stato": 'Italia',
    "geolocation": {
        "type": "Point", 
        "coordinates": [10.8444, 45.3493]
    }
}

{
    "location_name": 'Parco Nord',
    "citta": 'Bologna',
    "stato": 'Italia',
    "geolocation": {
        "type": "Point", 
        "coordinates": [11.3429, 44.5306]
    }
}

{
    "location_name": 'PalaDozza',
    "citta": 'Bologna',
    "stato": 'Italia',
    "geolocation": {
        "type": "Point", 
        "coordinates": [11.3269, 44.4989]
    }
}

{
    "location_name": 'Stadio Ennio Tardini',
    "citta": 'Parma',
    "stato": 'Italia',
    "geolocation": {
        "type": "Point", 
        "coordinates": [10.3346, 44.7956]
    }
}

#eventi
{ 
       "nome_evento": 'Gazzelle + Irbis',
       "id_artisti": [], /#gazzelle da inserire
       "data": '2024-07-12',
       "ora": '16:00:00',
       "id_location": , #padova geox
       "biglietti": {
            "disponibili":5000,
            "prezzo": 30,
            "id_ultimo_biglietto": 0,
       }
    }

{ 
       "nome_evento": 'Sfera Ebbasta - Tour Palasport',
       "id_artisti": [], /#sfera da inserire
       "data": '2024-12-1',
       "ora": '16:00:00',
       "id_location": , #padova villa contarini
       "biglietti": {
            "disponibili":5000,
            "prezzo": 30,
            "id_ultimo_biglietto": 0,
       }
    }

{ 
       "nome_evento": 'Francesco De Gregori dal vivo',
       "id_artisti": [], /#De Gregori da inserire
       "data": '2024-09-04',
       "ora": '16:00:00',
       "id_location": , #parma ennio tardini
       "biglietti": {
            "disponibili":5000,
            "prezzo": 30,
            "id_ultimo_biglietto": 0,
       }
    }

{ 
       "nome_evento": 'LAZZA Locura Tour - Bologna',
       "id_artisti": [], #lazza
       "data": '2025-01-31',
       "ora": '16:00:00',
       "id_location": , #bolo PalaDozza
       "biglietti": {
            "disponibili":5000,
            "prezzo": 30,
            "id_ultimo_biglietto": 0,
       }
    }

{ 
       "nome_evento": 'Heaven Tour - Bologna',
       "id_artisti": [],#Sum41
       "data": '2024-11-17',
       "ora": '16:00:00',
       "id_location": , #bologna parco nord
       "biglietti": {
            "disponibili":5000,
            "prezzo": 30,
            "id_ultimo_biglietto": 0,
       }
    }

{ 
       "nome_evento": 'Ghali - Live 2024',
       "id_artisti": [], #ghali
       "data": '2024-11-15',
       "ora": '16:00:00',
       "id_location": , #padova geox
       "biglietti": {
            "disponibili":5000,
            "prezzo": 30,
            "id_ultimo_biglietto": 0,
       }
    }

{ 
       "nome_evento": 'Paolo Nutini - Tour',
       "id_artisti": [], /#paolo nutini
       "data": '2024-10-14',
       "ora": '16:00:00',
       "id_location": , #arena
       "biglietti": {
            "disponibili":5000,
            "prezzo": 30,
            "id_ultimo_biglietto": 0,
       }
    }

{ 
       "nome_evento": 'Iron Maiden - World Tour',
       "id_artisti": [], #iron maiden
       "data": '2025-02-02',
       "ora": '16:00:00',
       "id_location": , #mediolanum forum 
       "biglietti": {
            "disponibili":5000,
            "prezzo": 30,
            "id_ultimo_biglietto": 0,
       }
    }

{ 
       "nome_evento": 'Calcutta Live',
       "id_artisti": [], #calcutta
       "data": '2024-12-05',
       "ora": '16:00:00',
       "id_location": , #vicenza teatro comunale
       "biglietti": {
            "disponibili":5000,
            "prezzo": 30,
            "id_ultimo_biglietto": 0,
       }
    }

{ 
       "nome_evento": 'ANNA Club Tour',
       "id_artisti": [], /#anna
       "data": '2024-11-30',
       "ora": '16:00:00',
       "id_location": , #ippodromo milano
       "biglietti": {
            "disponibili":5000,
            "prezzo": 30,
            "id_ultimo_biglietto": 0,
       }
    }

#artisti
{ // Artista 1
        '_id': 'A1'
        "artista": {"nome_arte": "Gazzelle", "nome": "Flavio", "cognome": "Pardini"},
        "lista_eventi": []
    },

{ // Artista 2
        '_id': 'A2'
        "artista": {"nome_arte": "Sfera Ebbasta", "nome": "Gionata", "cognome": "Boschetti"},
        "lista_eventi": []
    },

{ // Artista 3
        '_id': 'A3'
        "artista": {"nome_arte": "Francesco De Gregori", "nome": "", "cognome": ""},
        "lista_eventi": []
    },

{ // Artista 4
        '_id': 'A4'
        "artista": {"nome_arte": "Lazza", "nome": "Jacopo", "cognome": "Lazzarini"},
        "lista_eventi": []
    },

{ // Artista 5
        '_id': 'A5'
        "artista": {"nome_arte": "Ghali", "nome": "Ghali", "cognome": "Amdouni"},
        "lista_eventi": []
    },

{ // Artista 6
        '_id': 'A6'
        "artista": {"nome_arte": "Paolo Nutini", "nome": "Paolo", "cognome": "Nutini"},
        "lista_eventi": []
    },

{ // Artista 7
        '_id': 'A7'
        "artista": {"nome_arte": "Iron Maiden", "nome": '', "cognome": ''},
        "lista_eventi": []
    },

{ // Artista 8
        '_id': 'A8'
        "artista": {"nome_arte": "Calcutta", "nome": "Edoardo", "cognome": "D'erme"},
        "lista_eventi": []
    },

{ // Artista 9
        '_id': 'A9'
        "artista": {"nome_arte": "Ligabue", "nome": "Luciano", "cognome": "Ligabue"},
        "lista_eventi": []
    },

{ // Artista 10
        '_id': 'A10'
        "artista": {"nome_arte": "Anna", "nome": "Anna", "cognome": "Pepe"},
        "lista_eventi": []
    },
